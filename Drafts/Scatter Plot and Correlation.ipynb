# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
dataset = pd.read_csv('googleps_cleaned.csv')

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(dataset.iloc[:,1:9], alpha=0.2, figsize=(10, 10), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78D5E080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78D6A2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78DEA518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78E05780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78B259E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78B4FF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78B7F518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78BA8AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78BA8B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78C005C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78C25B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78C590F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78C81668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78CA8BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78CDA198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF78D01710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF79F6AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF79F9C240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF79FC47B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF79FECD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A01D2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A042860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A06CDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A09D390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A0C4908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A0EEE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A11D438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A1469B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A16FF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A19F4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A1C7A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A1F0FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A21F588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A245B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A27B0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A2A2630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A2C9BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A2F9160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A3226D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A34BC50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A37A208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A3A3780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A3CCCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A3FC2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A424828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A44DDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A47C358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A4A38D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A4CDE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A4FD400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A526978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A54EEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A57E4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A5A6A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A5CEF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A600550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A626AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A65A080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A6805F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A6A6B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A6D9128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A7026A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A729C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF7A75C1D0>]],
#       dtype=object)
