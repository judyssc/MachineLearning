# %% [markdown]
# # Google Play Store Data

# %% [markdown]
# ### Source:

# %% [markdown]
# https://www.kaggle.com/lava18/google-play-store-apps

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# - Remove all null value rows
# - Drop irrelevant columns
# - Perform encoding of values

# %%
import pandas as pd
#Read the file
df = pd.read_csv('googleplaystore.csv')

# %%
#Remove all the null value rows
dfclean = df.copy().dropna()

# %%
#drop irrelevant columns
to_drop =['App','Last Updated','Current Ver','Android Ver']

# %%
dfclean.drop(to_drop, inplace=True,axis =1)

# %%
#Categorizing the values of the Content Rating column
dict = {
    'Adults only 18+': 0,
    'Everyone': 1,
    'Everyone 10+': 2,
    'Mature 17+': 3,
    'Teen': 4,
    'Unrated': 5
}

dfclean['Content Rating'] = dfclean['Content Rating'].map(dict)

# %%
#Categorizing the values of the Category column
dict = {'ART_AND_DESIGN':0,
 'AUTO_AND_VEHICLES':1,
 'BEAUTY':2,
 'BOOKS_AND_REFERENCE':3,
 'BUSINESS':4,
 'COMICS':5,
 'COMMUNICATION':6,
 'DATING':7,
 'EDUCATION':8,
 'ENTERTAINMENT':9,
 'EVENTS':10,
 'FAMILY':11,
 'FINANCE':12,
 'FOOD_AND_DRINK':13,
 'GAME':14,
 'HEALTH_AND_FITNESS':15,
 'HOUSE_AND_HOME':16,
 'LIBRARIES_AND_DEMO':17,
 'LIFESTYLE':18,
 'MAPS_AND_NAVIGATION':19,
 'MEDICAL':20,
 'NEWS_AND_MAGAZINES':21,
 'PARENTING':22,
 'PERSONALIZATION':23,
 'PHOTOGRAPHY':24,
 'PRODUCTIVITY':25,
 'SHOPPING':26,
 'SOCIAL':27,
 'SPORTS':28,
 'TOOLS':29,
 'TRAVEL_AND_LOCAL':30,
 'VIDEO_PLAYERS':31,
 'WEATHER':32}

dfclean['Category'] = dfclean['Category'].map(dict)

# %%
#Categorizing the values of the Type column
set(dfclean['Type'])
# Out:
# {'Free', 'Paid'}

# %%
dict1 = {'Free':0, 'Paid':1}
dfclean['Type'] = dfclean['Type'].map(dict1)

# %%
#Categorizing the values of the Genre column
dict2 ={'Action':'Action',
 'Action;Action & Adventure':'Action',
 'Adventure':'Adventure',
 'Adventure;Action & Adventure':'Adventure',
 'Adventure;Brain Games':'Adventure',
 'Adventure;Education':'Adventure',
 'Arcade':'Arcade',
 'Arcade;Action & Adventure':'Arcade',
 'Arcade;Pretend Play':'Arcade',
 'Art & Design':'AD',
 'Art & Design;Creativity':'AD',
 'Art & Design;Pretend Play':'AD',
 'Auto & Vehicles':'AutoV',
 'Beauty':'Beauty',
 'Board':'Board',
 'Board;Brain Games':'Board',
 'Board;Pretend Play':'Board',
 'Books & Reference':'Books',
 'Books & Reference;Education':'Books',
 'Business':'Biz',
 'Card':'Card',
 'Card;Action & Adventure':'Card',
 'Card;Brain Games':'Card',
 'Casino':'Casino',
 'Casual':'Casual',
 'Casual;Action & Adventure':'Casual',
 'Casual;Brain Games':'Casual',
 'Casual;Creativity':'Casual',
 'Casual;Education':'Casual',
 'Casual;Music & Video':'Casual',
 'Casual;Pretend Play':'Casual',
 'Comics':'Comics',
 'Comics;Creativity':'Comics',
 'Communication':'Comms',
 'Communication;Creativity':'Comms',
 'Dating':'Dating',
 'Education':'Edu',
 'Education;Action & Adventure':'Edu',
 'Education;Brain Games':'Edu',
 'Education;Creativity':'Edu',
 'Education;Education':'Edu',
 'Education;Music & Video':'Edu',
 'Education;Pretend Play':'Edu',
 'Educational':'Edu',
 'Educational;Action & Adventure':'Edu',
 'Educational;Brain Games':'Edu',
 'Educational;Creativity':'Edu',
 'Educational;Education':'Edu',
 'Educational;Pretend Play':'Edu',
 'Entertainment':'Entmt',
 'Entertainment;Action & Adventure':'Entmt',
 'Entertainment;Brain Games':'Entmt',
 'Entertainment;Creativity':'Entmt',
 'Entertainment;Education':'Entmt',
 'Entertainment;Music & Video':'Entmt',
 'Entertainment;Pretend Play':'Entmt',
 'Events':'Events',
 'Finance':'Finance',
 'Food & Drink':'FD',
 'Health & Fitness':'Health',
 'Health & Fitness;Action & Adventure':'Health',
 'Health & Fitness;Education':'Health',
 'House & Home':'House',
 'Libraries & Demo':'LibDemo',
 'Lifestyle':'Lifestyle',
 'Lifestyle;Education':'Lifestyle',
 'Lifestyle;Pretend Play':'Lifestyle',
 'Maps & Navigation':'MapsNav',
 'Medical':'Med',
 'Music':'Music',
 'Music & Audio;Music & Video':'Music',
 'Music;Music & Video':'Music',
 'News & Magazines':'Books',
 'Parenting':'Parenting',
 'Parenting;Brain Games':'Parenting',
 'Parenting;Education':'Parenting',
 'Parenting;Music & Video':'Parenting',
 'Personalization':'Personal',
 'Photography':'Photo',
 'Productivity':'Prdt',
 'Puzzle':'Puzzle',
 'Puzzle;Action & Adventure':'Puzzle',
 'Puzzle;Brain Games':'Puzzle',
 'Puzzle;Creativity':'Puzzle',
 'Puzzle;Education':'Puzzle',
 'Racing':'Racing',
 'Racing;Action & Adventure':'Racing',
 'Racing;Pretend Play':'Racing',
 'Role Playing':'RoleP',
 'Role Playing;Action & Adventure':'RoleP',
 'Role Playing;Brain Games':'RoleP',
 'Role Playing;Pretend Play':'RoleP',
 'Shopping':'Shopping',
 'Simulation':'Simul',
 'Simulation;Action & Adventure':'Simul',
 'Simulation;Education':'Simul',
 'Simulation;Pretend Play':'Simul',
 'Social':'Social',
 'Sports':'Sports',
 'Sports;Action & Adventure':'Sports',
 'Strategy':'Strategy',
 'Strategy;Action & Adventure':'Strategy',
 'Strategy;Creativity':'Strategy',
 'Strategy;Education':'Strategy',
 'Tools':'Tools',
 'Tools;Education':'Tools',
 'Travel & Local':'Travel',
 'Travel & Local;Action & Adventure':'Travel',
 'Trivia':'Trivia',
 'Video Players & Editors':'Vid',
 'Video Players & Editors;Creativity':'Vid',
 'Video Players & Editors;Music & Video':'Vid',
 'Weather':'Weather',
 'Word':'Word',
 'Board;Action & Adventure':'Board'}

dfclean['Genres'] = dfclean['Genres'].map(dict2)

# %%
#Categorizing the values of the Installs column
dfclean
dfclean['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
set(dfclean['Installs'])
# Out:
# {'1+',
#  '1,000+',
#  '1,000,000+',
#  '1,000,000,000+',
#  '10+',
#  '10,000+',
#  '10,000,000+',
#  '100+',
#  '100,000+',
#  '100,000,000+',
#  '5+',
#  '5,000+',
#  '5,000,000+',
#  '50+',
#  '50,000+',
#  '50,000,000+',
#  '500+',
#  '500,000+',
#  '500,000,000+'}

# %%
set(dfclean['Price'])
# Out:
# {'$0.99',
#  '$1.00',
#  '$1.20',
#  '$1.29',
#  '$1.49',
#  '$1.50',
#  '$1.59',
#  '$1.61',
#  '$1.70',
#  '$1.75',
#  '$1.76',
#  '$1.97',
#  '$1.99',
#  '$10.00',
#  '$10.99',
#  '$11.99',
#  '$12.99',
#  '$13.99',
#  '$14.00',
#  '$14.99',
#  '$15.46',
#  '$15.99',
#  '$16.99',
#  '$17.99',
#  '$18.99',
#  '$19.40',
#  '$19.99',
#  '$2.00',
#  '$2.49',
#  '$2.50',
#  '$2.56',
#  '$2.59',
#  '$2.90',
#  '$2.95',
#  '$2.99',
#  '$24.99',
#  '$29.99',
#  '$299.99',
#  '$3.02',
#  '$3.04',
#  '$3.08',
#  '$3.28',
#  '$3.49',
#  '$3.88',
#  '$3.90',
#  '$3.95',
#  '$3.99',
#  '$33.99',
#  '$37.99',
#  '$379.99',
#  '$389.99',
#  '$39.99',
#  '$399.99',
#  '$4.29',
#  '$4.49',
#  '$4.59',
#  '$4.60',
#  '$4.77',
#  '$4.84',
#  '$4.99',
#  '$400.00',
#  '$5.49',
#  '$5.99',
#  '$6.49',
#  '$6.99',
#  '$7.49',
#  '$7.99',
#  '$79.99',
#  '$8.49',
#  '$8.99',
#  '$9.00',
#  '$9.99',
#  '0'}

# %%
dict3 = {'1+':1,
 '1,000+':2,
 '1,000,000+':3,
 '1,000,000,000+':4,
 '10+':5,
 '10,000+':6,
 '10,000,000+':7,
 '100+':8,
 '100,000+':9,
 '100,000,000+':10,
 '5+':11,
 '5,000+':12,
 '5,000,000+':13,
 '50+':14,
 '50,000+':15,
 '50,000,000+':16,
 '500+':17,
 '500,000+':18,
 '500,000,000+':19}

# %%
dfclean['Installs'] = dfclean['Installs'].map(dict3)

# %%
#Removing $ in front of Price Column
dfclean['Price'] = dfclean['Price'].str.replace('$','')

# %%
#Removing k and M values at the end of the Size Column
dfclean['Size'] = dfclean['Size'].str.rstrip('M')
dfclean['Size'] = dfclean['Size'].str.rstrip('k')

# %%
dfclean = dfclean[dfclean.Size != 'Varies with device']

# %%
dfclean
# Out:
#        Category  Rating Reviews Size  Installs  Type Price  Content Rating  \
# 0             0     4.1     159   19         6     0     0               1
# 1             0     3.9     967   14        18     0     0               1
# 2             0     4.7   87510  8.7        13     0     0               1
# 3             0     4.5  215644   25        16     0     0               4
# 4             0     4.3     967  2.8         9     0     0               1
# 5             0     4.4     167  5.6        15     0     0               1
# 6             0     3.8     178   19        15     0     0               1
# 7             0     4.1   36815   29         3     0     0               1
# 8             0     4.4   13791   33         3     0     0               1
# 9             0     4.7     121  3.1         6     0     0               1
# 10            0     4.4   13880   28         3     0     0               1
# ...

# %%
dfclean.to_csv("./googleps_cleaned.csv", sep=',',index=False)
